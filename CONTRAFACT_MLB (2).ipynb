# %%
from mkt_meas_sdk.task import BQTask, PythonTask

# %%
class CONTRAFACT_MLB(BQTask): # A BQTask will run a query and dump the results to a table with the same name as the class
    """This is the decription of our dataset and will be written on Fury"""
    
    materialization = "incremental" # This configures if we´re dropping the table or appending to it
    
    def depends_on(self):
        """
        This function must return a dict (may be empty)
            Key: 
                Any string that you want. This can be called in the template by the ref function
                Example: select * from {{ref("key")}}
            
            Value: 
                An imported class task. It doesn´t need to be instantiated
        
        Since the SDK controls the name of the table, we ask the ancestor task for the table name
        """
        return {}
    
    @staticmethod # REQUIRED: This tells python to attach a function to a class without passing self as first argument
    def get_dql_template():
        """
        This function must return a string with our query template. Note that it´s called Dql because
        we want only to describe how the data will be queried. 
        DO NOT:
        1. Create temp tables here
        1. Use DECLARE STATEMENTS
        
        DO:
        1. Use Common Table Expressions (WITH CTE AS (....))
        
        Jinja Templating:
            1. All jinja variables must be delimited by {{}}
            2. Favor using the ref function {{ref("my dependency")}}
        """
        
        sql = """
with nb as (
SELECT SIT_SITE_ID,
CAST(ORDER_CREATED_DTTM AS DATE) ORDER_CREATED_DATE,
COUNT(DISTINCT CUS_CUST_ID) NEW_BUYERS_AGMV
FROM `meli-marketing.OPSECOM.LK_ORDER_CUST_NRB_FLAGS`
WHERE
DATE(ORDER_CREATED_DTTM) >= '{{dt}}'
AND FLAG_NEW_BUYER_AGMV
GROUP BY 1, 2
ORDER BY 1, 2
),
sesiones as (
SELECT
  TIM_DAY,
  SIT_SITE_ID,
  SUM(SESSIONS_CANAL_INTERO) AS SESSIONS_INTERNO,
  SUM(SESSIONS_MARCARIAS) AS SESSIONS_MARCARIAS,
  SUM(SESSIONS_ORGANIC) AS SESSIONS_ORGANIC,
  SUM(SESSIONS_OTROS) AS SESSIONS_OTHERS,
  SUM(SESSIONS_PAGAS) AS SESSIONS_PAGAS
FROM
  `meli-marketing.MKTPUBLIC.V_BT_KPI_DAILY_ML_SUMMARY`
WHERE
  TIM_DAY >= '{{dt}}'
GROUP BY
  1,2
ORDER BY 1
),
gmv_competencia as (
SELECT
DATA,
sum(gmv_compre_confie) AS GMV_COMPETENCIA,
FROM `meli-bi-data.SBOX_MKPBR.DM_MARKETSHARE_DAILY` 
where data >= '{{dt}}'
GROUP BY 1
ORDER BY 1
),

 ORDERS_DATA AS (
SELECT ORD.ORD_CREATED_DT, ORD_ITEM.SHIPPING.FREE_SHIPPING_FLG,
CASE WHEN ORD_ITEM.SHIPPING.FREE_SHIPPING_FLG IS TRUE THEN COUNT(DISTINCT ORD.ORD_ORDER_ID) ELSE 0 END AS ORDERS_FREE_SHIPPING,
CASE WHEN ORD_ITEM.SHIPPING.FREE_SHIPPING_FLG IS FALSE THEN COUNT(DISTINCT ORD.ORD_ORDER_ID) ELSE 0 END AS ORDERS_NO_FREE_SHIPPING,
SUM(ORD_SHIPPING.COST) AS BUYER_SHIPPING_COST
FROM `meli-bi-data.WHOWNER.BT_ORD_ORDERS` ORD
LEFT JOIN `meli-bi-data.WHOWNER.LK_CURRENCY_CONVERTION` cc ON cc.SIT_SITE_ID = ORD.SIT_SITE_ID AND cc.TIM_DAY = ORD.ORD_CREATED_DT
WHERE ORD.SIT_SITE_ID = 'MLB'
AND ORD_TGMV_FLG IS TRUE
AND ORD_AUTO_OFFER_FLG IS FALSE
AND ORD_CLOSED_DT IS NOT NULL
AND ORD.ORD_CREATED_DT >= '{{dt}}'
AND CASE
            WHEN ORD.ORD_GMV_FLG = FALSE THEN FALSE
            WHEN ( COALESCE(ORD.ORD_ITEM.BASE_CURRENT_PRICE ,COALESCE(ORD.CC_USD_RATIO, cc.USD_RATIO) * ORD.ORD_ITEM.UNIT_PRICE, 0.0) < 10000.0
            AND ( ORD.ORD_CATEGORY.LEVELS[SAFE_OFFSET(0)].ID NOT IN (1459, 1743, 1540, 28, 5973) OR ORD.ORD_CATEGORY.LEVELS[SAFE_OFFSET(0)].ID IS NULL )
            AND ORD.SIT_SITE_ID NOT IN ('ABN', 'ASM', 'CCM')
            ) THEN TRUE
            ELSE FALSE
         END = TRUE
GROUP BY 1, 2),

COST AS (SELECT TIM_DAY,
SIT_SITE_ID,
cast(sum(COST_LC) as INT64) INVERSION
FROM `meli-marketing.MATT.V_BT_MATT_ML_TOOL` TB
WHERE  
ATTRIBUTION_TYPE = 'TIME DECAY 7 DAYS CALIB'
AND TIM_DAY >= '{{dt}}'
AND BUSINESS_UNIT = 'ML'
and SIT_SITE_ID = 'MLB'
group by 1,2
order by 1

),

DUMMIES AS (SELECT *
FROM `mkt-measurement.DUMMIES.MLB`
WHERE DATE >= '{{dt}}'
)

SELECT
  ODR_CREATED_DT,
  COUNT(DISTINCT ODR_ORDER_ID) AS ORDERS_COUNT,
  sessions_others,
   SESSIONS_INTERNO,
   SESSIONS_MARCARIAS,
   SESSIONS_ORGANIC,
  SESSIONS_PAGAS,
  NEW_BUYERS_AGMV,
  INVERSION,
  cast(g.GMV_COMPETENCIA as int64) GMV_COMPETENCIA,
  SUM(ORDERS_FREE_SHIPPING)/(SUM(ORDERS_NO_FREE_SHIPPING)+SUM(ORDERS_FREE_SHIPPING)) FREE_SHIPPING,
ISO_WEEK,
BB_AMERICANAS,
COMMERCIAL_DATE,
WEEKDAY,
HOLIDAY,
TEST_DUMMY

FROM
  sesiones a
  inner join `meli-bi-data.WHOWNER.BT_MATT_ATTRIBUTION_ML` b
  on a.SIT_SITE_ID=b.SIT_SITE_ID and a.TIM_DAY=b.ODR_CREATED_DT
  inner join nb 
  on a.SIT_SITE_ID=nb.SIT_SITE_ID and a.TIM_DAY=nb.ORDER_CREATED_DATE
  inner join gmv_competencia g
  On a.TIM_DAY = g.DATA
  inner join ORDERS_DATA d
  on g.data = d.ord_created_dt
  inner join COST inv
  on inv.tim_day = d.ord_created_dt
  inner join DUMMIES dm
  on inv.tim_day = dm.date
WHERE
  a.TIM_DAY >= '{{dt}}'
  AND a.SIT_SITE_ID= 'MLB'
group by 1,3,4,5,6,7,8,9,10,12,13,14,15,16,17
ORDER BY 1


"""
        return sql

# %%
from melitk.connectors import BigQuery
import json
import base64
from melitk.melipass import get_secret

credentials = json.loads(base64.b64decode(get_secret('GCP_CREDENTIALS')))

engine = BigQuery(credentials)

# %%
task = CONTRAFACT_MLB(engine)
# You can render the query
task.render(dt='2023-01-01')

# You can get the required inputs
task.get_task_inputs()
# Out:
# [2023-04-20 10:07:44-0400] INFO - prefect.FlowRunner | Beginning Flow run for '`meli-marketing.MEASUREMENT.contrafact_mlb`_render'
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'get_dql_template': Starting task run...
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'get_dql_template': Finished task run for task with final state: 'Success'
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'dt': Starting task run...
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'dt': Finished task run for task with final state: 'Success'
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'cartesian_product_of_parameters': Starting task run...
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'cartesian_product_of_parameters': Finished task run for task with final state: 'Success'
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'render_dql': Starting task run...
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'render_dql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Starting task run...
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'print': Starting task run...
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'print': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'print[0]': Starting task run...
#
#     with nb as (
# SELECT SIT_SITE_ID,
# CAST(ORDER_CREATED_DTTM AS DATE) ORDER_CREATED_DATE,
# COUNT(DISTINCT CUS_CUST_ID) NEW_BUYERS_AGMV
# FROM `meli-marketing.OPSECOM.LK_ORDER_CUST_NRB_FLAGS`
# WHERE
# DATE(ORDER_CREATED_DTTM) >= '2023-01-01'
# AND FLAG_NEW_BUYER_AGMV
# GROUP BY 1, 2
# ORDER BY 1, 2
# ),
# sesiones as (
# SELECT
#   TIM_DAY,
#   SIT_SITE_ID,
#   SUM(SESSIONS_CANAL_INTERO) AS SESSIONS_INTERNO,
#   SUM(SESSIONS_MARCARIAS) AS SESSIONS_MARCARIAS,
#   SUM(SESSIONS_ORGANIC) AS SESSIONS_ORGANIC,
#   SUM(SESSIONS_OTROS) AS SESSIONS_OTHERS,
#   SUM(SESSIONS_PAGAS) AS SESSIONS_PAGAS
# FROM
#   `meli-marketing.MKTPUBLIC.V_BT_KPI_DAILY_ML_SUMMARY`
# WHERE
#   TIM_DAY >= '2023-01-01'
# GROUP BY
#   1,2
# ORDER BY 1
# ),
# gmv_competencia as (
# SELECT
# DATA,
# sum(gmv_compre_confie) AS GMV_COMPETENCIA,
# FROM `meli-bi-data.SBOX_MKPBR.DM_MARKETSHARE_DAILY`
# where data >= '2023-01-01'
# GROUP BY 1
# ORDER BY 1
# ),
#
#  ORDERS_DATA AS (
# SELECT ORD.ORD_CREATED_DT, ORD_ITEM.SHIPPING.FREE_SHIPPING_FLG,
# CASE WHEN ORD_ITEM.SHIPPING.FREE_SHIPPING_FLG IS TRUE THEN COUNT(DISTINCT ORD.ORD_ORDER_ID) ELSE 0 END AS ORDERS_FREE_SHIPPING,
# CASE WHEN ORD_ITEM.SHIPPING.FREE_SHIPPING_FLG IS FALSE THEN COUNT(DISTINCT ORD.ORD_ORDER_ID) ELSE 0 END AS ORDERS_NO_FREE_SHIPPING,
# SUM(ORD_SHIPPING.COST) AS BUYER_SHIPPING_COST
# FROM `meli-bi-data.WHOWNER.BT_ORD_ORDERS` ORD
# LEFT JOIN `meli-bi-data.WHOWNER.LK_CURRENCY_CONVERTION` cc ON cc.SIT_SITE_ID = ORD.SIT_SITE_ID AND cc.TIM_DAY = ORD.ORD_CREATED_DT
# WHERE ORD.SIT_SITE_ID = 'MLB'
# AND ORD_TGMV_FLG IS TRUE
# AND ORD_AUTO_OFFER_FLG IS FALSE
# AND ORD_CLOSED_DT IS NOT NULL
# AND ORD.ORD_CREATED_DT >= '2023-01-01'
# AND CASE
#             WHEN ORD.ORD_GMV_FLG = FALSE THEN FALSE
#             WHEN ( COALESCE(ORD.ORD_ITEM.BASE_CURRENT_PRICE ,COALESCE(ORD.CC_USD_RATIO, cc.USD_RATIO) * ORD.ORD_ITEM.UNIT_PRICE, 0.0) < 10000.0
#             AND ( ORD.ORD_CATEGORY.LEVELS[SAFE_OFFSET(0)].ID NOT IN (1459, 1743, 1540, 28, 5973) OR ORD.ORD_CATEGORY.LEVELS[SAFE_OFFSET(0)].ID IS NULL )
#             AND ORD.SIT_SITE_ID NOT IN ('ABN', 'ASM', 'CCM')
#             ) THEN TRUE
#             ELSE FALSE
#          END = TRUE
# GROUP BY 1, 2),
#
# COST AS (SELECT TIM_DAY,
# SIT_SITE_ID,
# cast(sum(COST_LC) as INT64) INVERSION
# FROM `meli-marketing.MATT.V_BT_MATT_ML_TOOL` TB
# WHERE
# ATTRIBUTION_TYPE = 'TIME DECAY 7 DAYS CALIB'
# AND TIM_DAY >= '2023-01-01'
# AND BUSINESS_UNIT = 'ML'
# and SIT_SITE_ID = 'MLB'
# group by 1,2
# order by 1
#
# ),
#
# DUMMIES AS (SELECT *
# FROM `mkt-measurement.DUMMIES.MLB`
# WHERE DATE >= '2023-01-01'
# )
#
# SELECT
#   ODR_CREATED_DT,
#   COUNT(DISTINCT ODR_ORDER_ID) AS ORDERS_COUNT,
#   sessions_others,
#    SESSIONS_INTERNO,
#    SESSIONS_MARCARIAS,
#    SESSIONS_ORGANIC,
#   SESSIONS_PAGAS,
#   NEW_BUYERS_AGMV,
#   INVERSION,
#   cast(g.GMV_COMPETENCIA as int64) GMV_COMPETENCIA,
#   SUM(ORDERS_FREE_SHIPPING)/(SUM(ORDERS_NO_FREE_SHIPPING)+SUM(ORDERS_FREE_SHIPPING)) FREE_SHIPPING,
# ISO_WEEK,
# BB_AMERICANAS,
# COMMERCIAL_DATE,
# WEEKDAY,
# HOLIDAY,
# TEST_DUMMY
#
# FROM
#   sesiones a
#   inner join `meli-bi-data.WHOWNER.BT_MATT_ATTRIBUTION_ML` b
#   on a.SIT_SITE_ID=b.SIT_SITE_ID and a.TIM_DAY=b.ODR_CREATED_DT
#   inner join nb
#   on a.SIT_SITE_ID=nb.SIT_SITE_ID and a.TIM_DAY=nb.ORDER_CREATED_DATE
#   inner join gmv_competencia g
#   On a.TIM_DAY = g.DATA
#   inner join ORDERS_DATA d
#   on g.data = d.ord_created_dt
#   inner join COST inv
#   on inv.tim_day = d.ord_created_dt
#   inner join DUMMIES dm
#   on inv.tim_day = dm.date
# WHERE
#   a.TIM_DAY >= '2023-01-01'
#   AND a.SIT_SITE_ID= 'MLB'
# group by 1,3,4,5,6,7,8,9,10,12,13,14,15,16,17
# ORDER BY 1
#
#
# [2023-04-20 10:07:44-0400] INFO - prefect.TaskRunner | Task 'print[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:07:44-0400] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded
# ['dt']

# %%
task(dt='2023-01-01')
# Out:
# [2023-04-20 10:12:27-0400] INFO - prefect.FlowRunner | Beginning Flow run for '`meli-marketing.MEASUREMENT.contrafact_mlb`_render'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'dt': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'get_dql_template': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'dt': Finished task run for task with final state: 'Success'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'get_dql_template': Finished task run for task with final state: 'Success'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'cartesian_product_of_parameters': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'cartesian_product_of_parameters': Finished task run for task with final state: 'Success'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'render_dql': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'render_dql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'tablename': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'full_refresh': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'materialization': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'tablename': Finished task run for task with final state: 'Success'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'full_refresh': Finished task run for task with final state: 'Success'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'materialization': Finished task run for task with final state: 'Success'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'get_stg_table_name': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'get_stg_table_name': Finished task run for task with final state: 'Success'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'engine': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'engine': Finished task run for task with final state: 'Success'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'rendering_target_schema': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'rendering_target_schema': Finished task run for task with final state: 'Success'
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Task 'creating_target_table_schema': Starting task run...
# [2023-04-20 10:12:28-0400] INFO - prefect.TaskRunner | Executing query...
# [2023-04-20 10:13:50-0400] ERROR - prefect.TaskRunner | Task 'creating_target_table_schema': Exception encountered during task execution!
# Traceback (most recent call last):
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/engine/task_runner.py", line 880, in get_task_run_state
#     value = prefect.utilities.executors.run_task_with_timeout(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/utilities/executors.py", line 468, in run_task_with_timeout
#     return task.run(*args, **kwargs)  # type: ignore
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/mkt_meas_sdk/sql_utils.py", line 176, in execute_sql
#     engine.execute(sql)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/melitk/connectors/sources/bigquery/__init__.py", line 152, in execute
#     result.result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1499, in result
#     do_get_result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 349, in retry_wrapped_func
#     return retry_target(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 191, in retry_target
#     return target()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1489, in do_get_result
#     super(QueryJob, self).result(retry=retry, timeout=timeout)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/base.py", line 728, in result
#     return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/future/polling.py", line 261, in result
#     raise self._exception
# google.api_core.exceptions.BadRequest: 400 Access Denied: BigQuery BigQuery: Permission denied while getting Drive credentials. at [2:5]
#
# Location: US
# Job ID: 7b9d171b-91c2-494d-84af-590d608de599
#
# [2023-04-20 10:13:50-0400] INFO - prefect.TaskRunner | Task 'creating_target_table_schema': Finished task run for task with final state: 'Failed'
# [2023-04-20 10:13:50-0400] INFO - prefect.TaskRunner | Task 'move_data_sql': Starting task run...
# [2023-04-20 10:13:50-0400] INFO - prefect.TaskRunner | Task 'move_data_sql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:13:50-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target': Starting task run...
# [2023-04-20 10:13:50-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:13:50-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema[0]': Starting task run...
# [2023-04-20 10:13:50-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:13:50-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table[0]': Starting task run...
# [2023-04-20 10:13:50-0400] INFO - prefect.TaskRunner | Executing query...
# [2023-04-20 10:15:17-0400] ERROR - prefect.TaskRunner | Task 'computing_staging_table[0]': Exception encountered during task execution!
# Traceback (most recent call last):
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/engine/task_runner.py", line 880, in get_task_run_state
#     value = prefect.utilities.executors.run_task_with_timeout(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/utilities/executors.py", line 468, in run_task_with_timeout
#     return task.run(*args, **kwargs)  # type: ignore
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/mkt_meas_sdk/sql_utils.py", line 176, in execute_sql
#     engine.execute(sql)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/melitk/connectors/sources/bigquery/__init__.py", line 152, in execute
#     result.result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1499, in result
#     do_get_result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 349, in retry_wrapped_func
#     return retry_target(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 191, in retry_target
#     return target()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1489, in do_get_result
#     super(QueryJob, self).result(retry=retry, timeout=timeout)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/base.py", line 728, in result
#     return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/future/polling.py", line 261, in result
#     raise self._exception
# google.api_core.exceptions.BadRequest: 400 Access Denied: BigQuery BigQuery: Permission denied while getting Drive credentials. at [2:5]
#
# Location: US
# Job ID: a09eceb5-6849-48ef-95b6-ea4cd477dfef
#
# [2023-04-20 10:15:17-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table[0]': Finished task run for task with final state: 'Retrying'
# [2023-04-20 10:15:17-0400] INFO - prefect.TaskRunner | Task 'move_data_sql[0]': Starting task run...
# [2023-04-20 10:15:17-0400] INFO - prefect.TaskRunner | Task 'move_data_sql[0]': Finished task run for task with final state: 'Pending'
# [2023-04-20 10:15:17-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target[0]': Starting task run...
# [2023-04-20 10:15:17-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target[0]': Finished task run for task with final state: 'Pending'
# [2023-04-20 10:15:17-0400] INFO - prefect.FlowRunner | Flow run RUNNING: terminal tasks are incomplete.
# [2023-04-20 10:15:17-0400] INFO - prefect.`meli-marketing.MEASUREMENT.contrafact_mlb`_render | Waiting for next available Task run at 2023-04-20T14:15:32.748767+00:00
# [2023-04-20 10:15:32-0400] INFO - prefect.FlowRunner | Beginning Flow run for '`meli-marketing.MEASUREMENT.contrafact_mlb`_render'
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'render_dql': Starting task run...
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'render_dql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema': Starting task run...
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table': Starting task run...
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'move_data_sql': Starting task run...
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'move_data_sql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target': Starting task run...
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Starting task run...
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema[0]': Starting task run...
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table[0]': Starting task run...
# [2023-04-20 10:15:32-0400] INFO - prefect.TaskRunner | Executing query...
# [2023-04-20 10:17:05-0400] ERROR - prefect.TaskRunner | Task 'computing_staging_table[0]': Exception encountered during task execution!
# Traceback (most recent call last):
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/engine/task_runner.py", line 880, in get_task_run_state
#     value = prefect.utilities.executors.run_task_with_timeout(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/utilities/executors.py", line 468, in run_task_with_timeout
#     return task.run(*args, **kwargs)  # type: ignore
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/mkt_meas_sdk/sql_utils.py", line 176, in execute_sql
#     engine.execute(sql)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/melitk/connectors/sources/bigquery/__init__.py", line 152, in execute
#     result.result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1499, in result
#     do_get_result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 349, in retry_wrapped_func
#     return retry_target(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 191, in retry_target
#     return target()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1489, in do_get_result
#     super(QueryJob, self).result(retry=retry, timeout=timeout)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/base.py", line 728, in result
#     return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/future/polling.py", line 261, in result
#     raise self._exception
# google.api_core.exceptions.BadRequest: 400 Access Denied: BigQuery BigQuery: Permission denied while getting Drive credentials. at [2:5]
#
# Location: US
# Job ID: 7d84f4ff-491a-45b6-826d-6c98ffca4cf4
#
# [2023-04-20 10:17:05-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table[0]': Finished task run for task with final state: 'Retrying'
# [2023-04-20 10:17:05-0400] INFO - prefect.TaskRunner | Task 'move_data_sql[0]': Starting task run...
# [2023-04-20 10:17:05-0400] INFO - prefect.TaskRunner | Task 'move_data_sql[0]': Finished task run for task with final state: 'Pending'
# [2023-04-20 10:17:05-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target[0]': Starting task run...
# [2023-04-20 10:17:05-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target[0]': Finished task run for task with final state: 'Pending'
# [2023-04-20 10:17:05-0400] INFO - prefect.FlowRunner | Flow run RUNNING: terminal tasks are incomplete.
# [2023-04-20 10:17:05-0400] INFO - prefect.`meli-marketing.MEASUREMENT.contrafact_mlb`_render | Waiting for next available Task run at 2023-04-20T14:17:20.964621+00:00
# [2023-04-20 10:17:20-0400] INFO - prefect.FlowRunner | Beginning Flow run for '`meli-marketing.MEASUREMENT.contrafact_mlb`_render'
# [2023-04-20 10:17:20-0400] INFO - prefect.TaskRunner | Task 'render_dql': Starting task run...
# [2023-04-20 10:17:20-0400] INFO - prefect.TaskRunner | Task 'render_dql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema': Starting task run...
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table': Starting task run...
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'move_data_sql': Starting task run...
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'move_data_sql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target': Starting task run...
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Starting task run...
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema[0]': Starting task run...
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table[0]': Starting task run...
# [2023-04-20 10:17:21-0400] INFO - prefect.TaskRunner | Executing query...
# [2023-04-20 10:18:41-0400] ERROR - prefect.TaskRunner | Task 'computing_staging_table[0]': Exception encountered during task execution!
# Traceback (most recent call last):
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/engine/task_runner.py", line 880, in get_task_run_state
#     value = prefect.utilities.executors.run_task_with_timeout(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/utilities/executors.py", line 468, in run_task_with_timeout
#     return task.run(*args, **kwargs)  # type: ignore
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/mkt_meas_sdk/sql_utils.py", line 176, in execute_sql
#     engine.execute(sql)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/melitk/connectors/sources/bigquery/__init__.py", line 152, in execute
#     result.result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1499, in result
#     do_get_result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 349, in retry_wrapped_func
#     return retry_target(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 191, in retry_target
#     return target()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1489, in do_get_result
#     super(QueryJob, self).result(retry=retry, timeout=timeout)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/base.py", line 728, in result
#     return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/future/polling.py", line 261, in result
#     raise self._exception
# google.api_core.exceptions.BadRequest: 400 Access Denied: BigQuery BigQuery: Permission denied while getting Drive credentials. at [2:5]
#
# Location: US
# Job ID: 0af3d64f-7dc2-4abe-a9fe-27ecca0b550c
#
# [2023-04-20 10:18:41-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table[0]': Finished task run for task with final state: 'Retrying'
# [2023-04-20 10:18:41-0400] INFO - prefect.TaskRunner | Task 'move_data_sql[0]': Starting task run...
# [2023-04-20 10:18:41-0400] INFO - prefect.TaskRunner | Task 'move_data_sql[0]': Finished task run for task with final state: 'Pending'
# [2023-04-20 10:18:41-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target[0]': Starting task run...
# [2023-04-20 10:18:41-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target[0]': Finished task run for task with final state: 'Pending'
# [2023-04-20 10:18:41-0400] INFO - prefect.FlowRunner | Flow run RUNNING: terminal tasks are incomplete.
# [2023-04-20 10:18:41-0400] INFO - prefect.`meli-marketing.MEASUREMENT.contrafact_mlb`_render | Waiting for next available Task run at 2023-04-20T14:18:56.898287+00:00
# [2023-04-20 10:18:56-0400] INFO - prefect.FlowRunner | Beginning Flow run for '`meli-marketing.MEASUREMENT.contrafact_mlb`_render'
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'render_dql': Starting task run...
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'render_dql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema': Starting task run...
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table': Starting task run...
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'move_data_sql': Starting task run...
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'move_data_sql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target': Starting task run...
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:18:56-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Starting task run...
# [2023-04-20 10:18:57-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:18:57-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema[0]': Starting task run...
# [2023-04-20 10:18:57-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:18:57-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table[0]': Starting task run...
# [2023-04-20 10:18:57-0400] INFO - prefect.TaskRunner | Executing query...
# [2023-04-20 10:20:17-0400] ERROR - prefect.TaskRunner | Task 'computing_staging_table[0]': Exception encountered during task execution!
# Traceback (most recent call last):
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/engine/task_runner.py", line 880, in get_task_run_state
#     value = prefect.utilities.executors.run_task_with_timeout(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/utilities/executors.py", line 468, in run_task_with_timeout
#     return task.run(*args, **kwargs)  # type: ignore
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/mkt_meas_sdk/sql_utils.py", line 176, in execute_sql
#     engine.execute(sql)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/melitk/connectors/sources/bigquery/__init__.py", line 152, in execute
#     result.result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1499, in result
#     do_get_result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 349, in retry_wrapped_func
#     return retry_target(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 191, in retry_target
#     return target()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1489, in do_get_result
#     super(QueryJob, self).result(retry=retry, timeout=timeout)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/base.py", line 728, in result
#     return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/future/polling.py", line 261, in result
#     raise self._exception
# google.api_core.exceptions.BadRequest: 400 Access Denied: BigQuery BigQuery: Permission denied while getting Drive credentials. at [2:5]
#
# Location: US
# Job ID: ad7b5d50-680d-4d54-857d-e99c23a48aa5
#
# [2023-04-20 10:20:17-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table[0]': Finished task run for task with final state: 'Retrying'
# [2023-04-20 10:20:17-0400] INFO - prefect.TaskRunner | Task 'move_data_sql[0]': Starting task run...
# [2023-04-20 10:20:17-0400] INFO - prefect.TaskRunner | Task 'move_data_sql[0]': Finished task run for task with final state: 'Pending'
# [2023-04-20 10:20:17-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target[0]': Starting task run...
# [2023-04-20 10:20:17-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target[0]': Finished task run for task with final state: 'Pending'
# [2023-04-20 10:20:17-0400] INFO - prefect.FlowRunner | Flow run RUNNING: terminal tasks are incomplete.
# [2023-04-20 10:20:17-0400] INFO - prefect.`meli-marketing.MEASUREMENT.contrafact_mlb`_render | Waiting for next available Task run at 2023-04-20T14:20:32.083870+00:00
# [2023-04-20 10:20:32-0400] INFO - prefect.FlowRunner | Beginning Flow run for '`meli-marketing.MEASUREMENT.contrafact_mlb`_render'
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'render_dql': Starting task run...
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'render_dql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema': Starting task run...
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table': Starting task run...
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'move_data_sql': Starting task run...
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'move_data_sql': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target': Starting task run...
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target': Finished task run for task with final state: 'Mapped'
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Starting task run...
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'render_dql[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema[0]': Starting task run...
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'rendering_staging_schema[0]': Finished task run for task with final state: 'Success'
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table[0]': Starting task run...
# [2023-04-20 10:20:32-0400] INFO - prefect.TaskRunner | Executing query...
# [2023-04-20 10:21:38-0400] ERROR - prefect.TaskRunner | Task 'computing_staging_table[0]': Exception encountered during task execution!
# Traceback (most recent call last):
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/engine/task_runner.py", line 880, in get_task_run_state
#     value = prefect.utilities.executors.run_task_with_timeout(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/prefect/utilities/executors.py", line 468, in run_task_with_timeout
#     return task.run(*args, **kwargs)  # type: ignore
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/mkt_meas_sdk/sql_utils.py", line 176, in execute_sql
#     engine.execute(sql)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/melitk/connectors/sources/bigquery/__init__.py", line 152, in execute
#     result.result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1499, in result
#     do_get_result()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 349, in retry_wrapped_func
#     return retry_target(
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/retry.py", line 191, in retry_target
#     return target()
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/query.py", line 1489, in do_get_result
#     super(QueryJob, self).result(retry=retry, timeout=timeout)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/cloud/bigquery/job/base.py", line 728, in result
#     return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#   File "/root/.cache/pypoetry/virtualenvs/app-ckvPxAjg-py3.8/lib/python3.8/site-packages/google/api_core/future/polling.py", line 261, in result
#     raise self._exception
# google.api_core.exceptions.BadRequest: 400 Access Denied: BigQuery BigQuery: Permission denied while getting Drive credentials. at [2:5]
#
# Location: US
# Job ID: ab2e57cd-dcde-4d62-9f11-ec51f79de3a7
#
# [2023-04-20 10:21:38-0400] INFO - prefect.TaskRunner | Task 'computing_staging_table[0]': Finished task run for task with final state: 'Failed'
# [2023-04-20 10:21:38-0400] INFO - prefect.TaskRunner | Task 'move_data_sql[0]': Starting task run...
# [2023-04-20 10:21:38-0400] INFO - prefect.TaskRunner | Task 'move_data_sql[0]': Finished task run for task with final state: 'TriggerFailed'
# [2023-04-20 10:21:38-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target[0]': Starting task run...
# [2023-04-20 10:21:38-0400] INFO - prefect.TaskRunner | Task 'moving_from_staging_to_target[0]': Finished task run for task with final state: 'TriggerFailed'
# [2023-04-20 10:21:38-0400] INFO - prefect.FlowRunner | Flow run FAILED: some reference tasks failed.
